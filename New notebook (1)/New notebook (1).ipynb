# %%
first = [1,2,3,4]
second = first.copy()
second_direct_copy= first

print(id(first))
print(id(second))
print(id(second_direct_copy))

first.append(11)

print(second_direct_copy)
# Out:
# 140559972652224
# 140559972764864
# 140559972652224
# [1, 2, 3, 4, 11]
