# %%
import pandas as pd
import numpy as np
import sci

# %%
df = pd.read_csv('/data/notebook_files/Travel details dataset.csv')

# %%
df.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Trip ID</th>
#       <th>Destination</th>
#       <th>Start date</th>
#       <th>End date</th>
#       <th>Duration (days)</th>
#       <th>Traveler name</th>
#       <th>Traveler age</th>
#       <th>Traveler gender</th>
#       <th>Traveler nationality</th>
#       <th>Accommodation type</th>
#       <th>Accommodation cost</th>
#       <th>Transportation type</th>
#       <th>Transportation cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>London, UK</td>
#       <td>5/1/2023</td>
#       <td>5/8/2023</td>
#       <td>7.0</td>
# ...

# %%
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Trip ID</th>
#       <th>Duration (days)</th>
#       <th>Traveler age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>139.000000</td>
#       <td>137.000000</td>
#       <td>137.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>70.000000</td>
#       <td>7.605839</td>
#       <td>33.175182</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>40.269923</td>
#       <td>1.601276</td>
#       <td>7.145441</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.000000</td>
#       <td>5.000000</td>
#       <td>20.000000</td>
#     </tr>
# ...
